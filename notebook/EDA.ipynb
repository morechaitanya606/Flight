# %%
import pandas as pd
import numpy as np 
import eda_helper_functions as eda

# %%
file_path = r"C:\Users\Chaitanya\OneDrive\Desktop\project\Flight\flight\data\train.csv"

train = pd.read_csv(file_path)
train
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0              Vistara      2019-05-21   Kolkata    Banglore  17:00:00
# 1             Spicejet      2019-05-09   Kolkata    Banglore  06:55:00
# 2             Air Asia      2019-05-12   Kolkata    Banglore  22:40:00
# 3          Jet Airways      2019-05-27     Delhi      Cochin  11:30:00
# 4    Multiple Carriers      2019-05-09     Delhi      Cochin  11:25:00
# ..                 ...             ...       ...         ...       ...
# 635        Jet Airways      2019-03-15  Banglore   New Delhi  05:45:00
# 636        Jet Airways      2019-04-06     Delhi      Cochin  13:00:00
# 637        Jet Airways      2019-05-24   Kolkata    Banglore  18:55:00
# 638        Jet Airways      2019-04-09     Delhi      Cochin  11:40:00
# 639           Air Asia      2019-03-24   Kolkata    Banglore  22:50:00
#
#     arrival_time  duration  total_stops              additional_info  price
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   airline          640 non-null    object
#  1   date_of_journey  640 non-null    object
#  2   source           640 non-null    object
#  3   destination      640 non-null    object
#  4   dep_time         640 non-null    object
#  5   arrival_time     640 non-null    object
#  6   duration         640 non-null    int64
#  7   total_stops      640 non-null    float64
#  8   additional_info  640 non-null    object
#  9   price            640 non-null    int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 50.1+ KB

# %%
eda.missing_info(train)
# Out:
# Empty DataFrame
# Columns: [count, percentage]
# Index: []

# %% [markdown]
# ### No missing values in the dataset

# %%
eda_helper_functions.cat_univar_plots(train, "airline")
# Out:
# <h2>Univariate Analysis of airline</h2>
# <h3></h3>

# %%
eda.cat_bivar_plots(data=train,var1="airline",var2="source")
# Out:
# <h2>Bi-variate Analysis between airline and source</h2>
# <h3></h3>

# %%
eda.cat_univar_plots(data=train,var="airline")
# Out:
# <h2>Univariate Analysis of airline</h2>
# <h3></h3>

# %%
eda.dt_univar_plots(data=train,var="airline",target="source")
# Out:
# <h3>Univariate plots of airline</h3>

# %%
eda.num_cat_bivar_plots(data=train,num_var="duration",cat_var="source",estimator='mean',order=None)
# Out:
# <h2>Bi-variate Analysis between source and duration</h2>
# <h3></h3>
